# %%
import matplotlib.pyplot as mplt
# %matplotlib inline

# %%
import  pandas as pd

# %%
df = pd.read_csv("C:/Users/Askim/Downloads/data_2023-Dec-14.csv")
df
# Out:
#      areaType areaName   areaCode        date  newCasesBySpecimenDate  \
# 0      nation  England  E92000001  2023-12-13                     583
# 1      nation  England  E92000001  2023-12-12                    1040
# 2      nation  England  E92000001  2023-12-11                    1183
# 3      nation  England  E92000001  2023-12-10                     947
# 4      nation  England  E92000001  2023-12-09                     771
# ...       ...      ...        ...         ...                     ...
# 1409   nation  England  E92000001  2020-02-03                      18
# 1410   nation  England  E92000001  2020-02-02                       1
# 1411   nation  England  E92000001  2020-02-01                       0
# 1412   nation  England  E92000001  2020-01-31                       0
# 1413   nation  England  E92000001  2020-01-30                       1
#
#       cumCasesBySpecimenDate  newFirstEpisodesBySpecimenDate  \
# 0                   21024823                             294
# ...

# %%
Sorted_df = df.sort_values(by='date', ascending = True)

# %%
x = Sorted_df['date']

# %%
x
# Out:
# 1413    2020-01-30
# 1412    2020-01-31
# 1411    2020-02-01
# 1410    2020-02-02
# 1409    2020-02-03
#            ...
# 4       2023-12-09
# 3       2023-12-10
# 2       2023-12-11
# 1       2023-12-12
# 0       2023-12-13
# Name: date, Length: 1414, dtype: object

# %%
y = Sorted_df['newCasesBySpecimenDate'].round(5)
y
# Out:
# 1413       1
# 1412       0
# 1411       0
# 1410       1
# 1409      18
#         ...
# 4        771
# 3        947
# 2       1183
# 1       1040
# 0        583
# Name: newCasesBySpecimenDate, Length: 1414, dtype: int64

# %%
mplt.plot(x, y)

# %%
import mplcursors
fig = mplt.figure(figsize=(18,8))
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x, y)
axes.set_title('Covid Cases in UK')
mplcursors.cursor(hover = True)
mplt.show()

# %%
fig.savefig('CoronaVirusAnalysisUK.png')
